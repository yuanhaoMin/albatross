# %%
from langchain.document_loaders import WebBaseLoader

# %%
loader = WebBaseLoader("https://store.steampowered.com/app/814380/Sekiro_Shadows_Die_Twice__GOTY_Edition/")
data = loader.load()

# %%
print(data)
# Out:
# [Document(page_content='\n\n\n\n\n\nSekiro™: Shadows Die Twice - GOTY Edition on Steam\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n$J = jQuery.noConflict();VALVE_PUBLIC_PATH = "https:\\/\\/store.cloudflare.steamstatic.com\\/public\\/";\n\n\n\nObject.seal && [ Object, Array, String, Number ].map( function( builtin ) { Object.seal( builtin.prototype ); } );\n\r\n\t\t\tdocument.addEventListener(\'DOMContentLoaded\', function(event) {\r\n\t\t\t\t$J.data( document, \'x_readytime\', new Date().getTime() );\r\n\t\t\t\t$J.data( document, \'x_oldref\', GetNavCookie() );\r\n\t\t\t\tSetupTooltips( { tooltipCSSClass: \'store_tooltip\'} );\r\n\t\t});\r\n\t\t\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\r\n\t\t\t\t\t\t\t\t\tLogin\t\t\t\t\t\t\t\t\n\r\n\t\tStore\t\n\nHome\nDiscovery Queue\nWishlist\nPoints Shop\nNews\nStats\n\n\r\n\t\t\tCommunity\t\t\n\nHome\nDiscussions\nWorkshop\nMarket\nBroadcasts\n\n\r\n\t\tSupport\t\n\n\r\n\t\t\t\t\t\t\t\t\tChange language\t\t\t\t\t\t\t\t\n\r\n\t\t\t\
# ...
